# %% [markdown]
# # To perform MACSE alignment

# %%
import os
import subprocess
from concurrent.futures import ThreadPoolExecutor

def run_macse(input_path, output_path, java_path, macse_jar_path):
    # Run MACSE using subprocess
    macse_cmd = [
        java_path,
        '-jar', macse_jar_path,
        '-prog', 'alignSequences',
        '-seq', input_path,
        '-out_NT', output_path,
    ]

    try:
        result = subprocess.run(macse_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True, text=True)
        print(result.stdout)
        print(result.stderr)

        print(f"Alignment for {input_path} completed. Output saved to {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Error during alignment for {input_path}. Details:\n{e}")

def convert_to_phylip(input_path, output_path, java_path, macse_jar_path):
    # Run MACSE AlignmentConverter to convert to PHYLIP format
    converter_cmd = [
        java_path,
        '-jar', macse_jar_path,
        '-prog', 'AlignmentConverter',
        '-in', input_path,
        '-out_PHYLIP', output_path,
    ]

    subprocess.run(converter_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    print(f"Conversion of {input_path} to PHYLIP format completed. Output saved to {output_path}")

def align_and_convert_parallel(orthogroup_folder, output_folder, num_threads, java_path, macse_jar_path):
    # Get a list of input FASTA files (one per orthogroup)
    input_files = [f for f in os.listdir(orthogroup_folder) if f.endswith('.fasta')]
    
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        # Generate a list of (input_path, output_path) tuples
        input_output_paths = [
            (os.path.join(orthogroup_folder, input_file), os.path.join(output_folder, input_file.replace('.fasta', '_aligned.fasta')))
            for input_file in input_files
        ]

        # Submit tasks to align sequences
        align_futures = [executor.submit(run_macse, input_path, output_path, java_path, macse_jar_path) for input_path, output_path in input_output_paths]

        # Wait for all alignment tasks to complete
        for future in align_futures:
            future.result()

        # Generate a list of (aligned_input_path, phylip_output_path) tuples
        aligned_phylip_paths = [
            (output_path, os.path.join(output_folder, os.path.basename(output_path).replace('_aligned.fasta', '_aligned.phylip')))
            for _, output_path in input_output_paths
        ]

        # Submit tasks to convert to PHYLIP format
        convert_futures = [executor.submit(convert_to_phylip, input_path, output_path, java_path, macse_jar_path) for input_path, output_path in aligned_phylip_paths]

        # Wait for all conversion tasks to complete
        for future in convert_futures:
            future.result()

# Specify the paths and parameters
orthogroup_folder = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files'
output_folder = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files'
num_threads = 4  # Adjust the number of threads based on your system's capabilities

# Specify the full path to the MACSE JAR file
macse_jar_path = '/usr2/people/shollyt22/macse_v2.07.jar'

# Obtain the Java path
java_path_result = subprocess.run(['which', 'java'], capture_output=True, text=True)
java_path = java_path_result.stdout.strip()

# Run the alignment script
align_and_convert_parallel(orthogroup_folder, output_folder, num_threads, java_path, macse_jar_path)
# Out:
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000785.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1046942.7
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1046942.7
# ........................++..+....+..................+...+..+
# refine 2 cut : sum of pairs ========= 1 => 1048277.3
# .............................-..............................
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000785_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000785_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000785.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000785_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000877.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1094068.2
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1094068.2
# .-.....++.+...++........+.+....+..++++++.+.++......++.++.++.
# refine 2 cut : sum of pairs ========= 1 => 1097572.9
# .-................++..........+....+..............+....+.+..
# refine 2 cut : sum of pairs ========= 2 => 1097696.9
# .-................+.........................................
# refine 2 cut : sum of pairs ========= 3 => 1097714.9
# .-.................-----------------------------------------
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000877_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000877_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000877.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000877_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000957.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 675372.5
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 675372.5
# .................+...+.........++.+++++..++++......+......++
# refine 2 cut : sum of pairs ========= 1 => 682924.1
# ++...........................+++...............+.+..........
# refine 2 cut : sum of pairs ========= 2 => 683470.3
# .....................+.........................++..++.......
# refine 2 cut : sum of pairs ========= 3 => 683707.3
# -..........+.........+..................................+...
# refine 2 cut : sum of pairs ========= 4 => 683749.3
# ....................+..............................+...+....
# refine 2 cut : sum of pairs ========= 5 => 683955.3
# .+...........+............+...............+.......++........
# refine 2 cut : sum of pairs ========= 6 => 684135.3
# ............+..........................+....................
# refine 2 cut : sum of pairs ========= 7 => 684168.3
# .............................-.........--------------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000957_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000957_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000957.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000957_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000757.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 913560.5
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 913560.5
# ............+...+.+..+++.+...+.+++++.+++++.+++++++++....++++
# refine 2 cut : sum of pairs ========= 1 => 923866.8
# +.....+....+...+...+.........+......++.++.++++...+.++.+++.++
# refine 2 cut : sum of pairs ========= 2 => 926724.3
# +............+...............+...+.+.....+++....++..........
# refine 2 cut : sum of pairs ========= 3 => 927416.9
# +....................+..........+...................+.......
# refine 2 cut : sum of pairs ========= 4 => 927555.9
# .............................-....................------.-..
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000757_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000757_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000757.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000757_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000683.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1919095.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1919095.4
# .............................-........++++++.+.....+......++
# refine 2 cut : sum of pairs ========= 1 => 1920960.4
# +...+...........................+.................+.........
# refine 2 cut : sum of pairs ========= 2 => 1921124.4
# ..................+........................................+
# refine 2 cut : sum of pairs ========= 3 => 1921134.4
# .............................-..............................
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000683_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000683_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000683.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000683_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001039.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 540149.2
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 540149.2
# .........+......+............++..+...............+.........+
# refine 2 cut : sum of pairs ========= 1 => 541114.2
# +..........................................................+
# refine 2 cut : sum of pairs ========= 2 => 541145.2
# .............................-..............................
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001039_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001039_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001039.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001039_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001055.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 735843.0
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 735843.0
# +...+.................+.......++..++++.......+..............
# refine 2 cut : sum of pairs ========= 1 => 736591.0
# ...............................+......................+.....
# refine 2 cut : sum of pairs ========= 2 => 736622.0
# ....................................................------..
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001055_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001055_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001055.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001055_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001062.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1419885.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1419885.4
# ...................+.........+.++.+.......+.++.............+
# refine 2 cut : sum of pairs ========= 1 => 1421146.1
# +......................................................+.+..
# refine 2 cut : sum of pairs ========= 2 => 1421243.1
# .............................-.......................+......
# refine 2 cut : sum of pairs ========= 3 => 1421363.1
# .............................-.......................------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001062_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001062_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001062.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001062_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001064.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 516671.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 516671.4
# .....++..++.+.+.++++....++...+++.+++++.++..+++.++++.....++++
# refine 2 cut : sum of pairs ========= 1 => 530601.8
# +......+.......+.........+..........++..++.+...++.+.........
# refine 2 cut : sum of pairs ========= 2 => 531558.6
# ...............+.....+..+.........+...................++.++.
# refine 2 cut : sum of pairs ========= 3 => 531927.3
# .............................-..................-+..........
# refine 2 cut : sum of pairs ========= 4 => 532115.4
# .............................-....+.+....+..............+...
# refine 2 cut : sum of pairs ========= 5 => 532212.4
# .............................-.......................---....
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001064_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001064_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001064.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001064_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001010.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1181047.8
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1181047.8
# ....+..........+........++++...+..........+......+.++......+
# refine 2 cut : sum of pairs ========= 1 => 1189912.0
# ........................+...........+...................++.+
# refine 2 cut : sum of pairs ========= 2 => 1190087.2
# .............................-..............................
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001010_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001010_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001010.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001010_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001139.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 969185.6
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 969185.6
# ..........+.++++.+++++.+++.+.+..+++++++..+++++.+.++++...++++
# refine 2 cut : sum of pairs ========= 1 => 985985.5
# ....+..............+.+..+....++.......+.++++...++.+.+.+.....
# refine 2 cut : sum of pairs ========= 2 => 987335.6
# +...+............+...+......+..........++.......+.+.++......
# refine 2 cut : sum of pairs ========= 3 => 987925.6
# .....+.......+...........................+.....+.........+..
# refine 2 cut : sum of pairs ========= 4 => 988343.6
# ..............................................--..+....+....
# refine 2 cut : sum of pairs ========= 5 => 988393.6
# -...................+.......................................
# refine 2 cut : sum of pairs ========= 6 => 988521.6
# -....................---------------------------------------
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001139_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001139_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001139.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001139_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000893.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 2231397.2
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 2231397.2
# ...........+...+....+..++.+..++++++++++.+++++++.++++.....+++
# refine 2 cut : sum of pairs ========= 1 => 2249149.5
# +++++.....+..........++.++.....+.....+++..+...++....+++..+++
# refine 2 cut : sum of pairs ========= 2 => 2252325.8
# +..+................+...+......++.+...+.+.......++++.+......
# refine 2 cut : sum of pairs ========= 3 => 2253096.5
# +......................................+........+.+.+.....+.
# refine 2 cut : sum of pairs ========= 4 => 2253293.2
# ............+...........+......+........+..+................
# refine 2 cut : sum of pairs ========= 5 => 2253364.5
# +...........................................................
# refine 2 cut : sum of pairs ========= 6 => 2253398.5
# ------------------------------------------------------------
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000893_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000893_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0000893.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0000893_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001137.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1471195.2
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1471195.2
# ......+...+...+.+.+.+.+.++...++.+..+++++++++++.++.++++..++.+
# refine 2 cut : sum of pairs ========= 1 => 1483982.2
# ...+....+..........+....+........+..........+++....++..+.+..
# refine 2 cut : sum of pairs ========= 2 => 1484490.2
# ................................-........-...+.......+++....
# refine 2 cut : sum of pairs ========= 3 => 1484731.2
# ...+....+.................................+...............+.
# refine 2 cut : sum of pairs ========= 4 => 1484739.2
# ................................-......+....................
# refine 2 cut : sum of pairs ========= 5 => 1484754.2
# ................................-......--------------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001137_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001137_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001137.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001137_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001154.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 850931.0
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 850931.0
# .........+...................++++.....++....++..+.+.......++
# refine 2 cut : sum of pairs ========= 1 => 853252.0
# ...+............................+.+................+........
# refine 2 cut : sum of pairs ========= 2 => 853416.0
# ...................................-..--...........------...
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001154_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001154_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001154.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001154_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001152.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1045299.1
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1045299.1
# ......+...............+.........+.............+..+....++.+..
# refine 2 cut : sum of pairs ========= 1 => 1045749.3
# .+..........................................................
# refine 2 cut : sum of pairs ========= 2 => 1045840.9
# -.----------------------------------------------------------
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001152_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001152_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001152.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001152_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001136.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1158011.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1158011.4
# ......+.++.++..++.++++...+...++++++++++++++++.++++++++.++.++
# refine 2 cut : sum of pairs ========= 1 => 1184269.9
# +.........+++...+.+.+...+.......+++++++.++.+..+.+...+.....++
# refine 2 cut : sum of pairs ========= 2 => 1187160.8
# +..................+....+...........+.++..+...+++++..+..+...
# refine 2 cut : sum of pairs ========= 3 => 1187728.8
# ++.......+.++.........+...+.....+...+....+.++.........++.++.
# refine 2 cut : sum of pairs ========= 4 => 1188500.2
# .........+....................++.+....................+.++.+
# refine 2 cut : sum of pairs ========= 5 => 1188915.0
# +......+...+............................+....+...+.+...+..+.
# refine 2 cut : sum of pairs ========= 6 => 1189017.2
# .......+............................+.+..............+......
# refine 2 cut : sum of pairs ========= 7 => 1189316.2
# +...................................+.......................
# refine 2 cut : sum of pairs ========= 8 => 1189329.2
# .............................-......-----------------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001136_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001136_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001136.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001136_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001199.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 875544.0
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 875544.0
# ..+.......+++..+..++..+......++++.........+.....++..++++...+
# refine 2 cut : sum of pairs ========= 1 => 879313.6
# ................................................-..+........
# refine 2 cut : sum of pairs ========= 2 => 879349.6
# ..........+.................................................
# refine 2 cut : sum of pairs ========= 3 => 879351.6
# -..........-------------------------------------------------
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001199_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001199_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001199.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001199_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001172.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1741441.2
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1741441.2
# .............................-.+..........+.........+.......
# refine 2 cut : sum of pairs ========= 1 => 1741696.4
# .............................-....................-------...
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001172_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001172_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001172.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001172_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001223.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1087316.0
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1087316.0
# .-.........+.+....+.+.....+..++.+.+..+..++..+++....+......+.
# refine 2 cut : sum of pairs ========= 1 => 1089674.0
# +...................+.......+...................+.......+...
# refine 2 cut : sum of pairs ========= 2 => 1089958.0
# -............................-..........+....+....+.........
# refine 2 cut : sum of pairs ========= 3 => 1090058.0
# .............................-.+...........................+
# refine 2 cut : sum of pairs ========= 4 => 1090131.0
# ............................+...............+...............
# refine 2 cut : sum of pairs ========= 5 => 1090165.0
# ..................+...........+.....................+.......
# refine 2 cut : sum of pairs ========= 6 => 1090304.0
# .............................-..................-------.....
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001223_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001223_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001223.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001223_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001215.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1442104.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1442104.4
# .-.............................+................++........++
# refine 2 cut : sum of pairs ========= 1 => 1442555.4
# +......................................................+....
# refine 2 cut : sum of pairs ========= 2 => 1442599.4
# .-.................................--....................--.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001215_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001215_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001215.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001215_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001235.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 662295.1
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 662295.1
# ....+.............+...........++++++.+....+.......+..+....+.
# refine 2 cut : sum of pairs ========= 1 => 663290.9
# .............................-.....-.............++..++.++..
# refine 2 cut : sum of pairs ========= 2 => 663334.9
# +.....+....+......................++...............+.+++.++.
# refine 2 cut : sum of pairs ========= 3 => 664687.9
# +...+.........................................+........+.+..
# refine 2 cut : sum of pairs ========= 4 => 664759.1
# .............................-.......................++.....
# refine 2 cut : sum of pairs ========= 5 => 664778.1
# .............................-........+.....................
# refine 2 cut : sum of pairs ========= 6 => 664836.1
# .............................-........---------------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001235_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001235_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001235.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001235_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001236.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1131565.0
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1131565.0
# .......+..+.+.....+.++..+....++....++..+.++++..+..++....+..+
# refine 2 cut : sum of pairs ========= 1 => 1136825.2
# ...............+........+........................+.+........
# refine 2 cut : sum of pairs ========= 2 => 1136885.8
# .............................................-..--------....
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001236_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001236_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001236.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001236_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001275.fasta
# 30	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ..............................
# compute first alignment with guide tree
# +++++++++++++++++++++++++++++
# first alignment score : 446081.5
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 446081.5
# ...++..++..+.........+.+.+..+..+++.++++++++..+.........+++
# refine 2 cut : sum of pairs ========= 1 => 454224.2
# .........................+...++..........+.+.+..++.+.+...+
# refine 2 cut : sum of pairs ========= 2 => 455615.6
# +...+...+...............+...+.++.+...+.+++......+....+..++
# refine 2 cut : sum of pairs ========= 3 => 456745.5
# +...+....................+.....+.....+.....+......+..+.+..
# refine 2 cut : sum of pairs ========= 4 => 456880.7
# ..........................+.....+........+............+...
# refine 2 cut : sum of pairs ========= 5 => 456924.8
# ............................-....................---......
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001275_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001275_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001275.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001275_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001266.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 992339.8
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 992339.8
# .-.....+++..+.....+..++++.+..++++..++..+++++++.+++++++.+.+++
# refine 2 cut : sum of pairs ========= 1 => 1019332.7
# +..+..+.+++..+....+.....+........+..+++..+++...+...++++..+..
# refine 2 cut : sum of pairs ========= 2 => 1021940.7
# .-........++...........+......+....+..................+.....
# refine 2 cut : sum of pairs ========= 3 => 1022243.7
# .-........................................+.+......+........
# refine 2 cut : sum of pairs ========= 4 => 1022268.7
# .-................+..................+.........+............
# refine 2 cut : sum of pairs ========= 5 => 1022448.7
# .-....................+...................................+.
# refine 2 cut : sum of pairs ========= 6 => 1022479.7
# .-..........+..........................+....................
# refine 2 cut : sum of pairs ========= 7 => 1022515.7
# .-.....................................--------------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001266_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001266_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001266.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001266_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001300.fasta
# 30	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ..............................
# compute first alignment with guide tree
# +++++++++++++++++++++++++++++
# first alignment score : 513574.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 513574.4
# .......+...+.+....+.+++........+.++++++++...+..+++....++++
# refine 2 cut : sum of pairs ========= 1 => 524078.5
# +.......................++..++++....+..+...+.+.....+++++++
# refine 2 cut : sum of pairs ========= 2 => 525631.5
# .......+.........................+.........+........++...+
# refine 2 cut : sum of pairs ========= 3 => 525886.5
# ..............................-...........................
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001300_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001300_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001300.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001300_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001313.fasta
# 30	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ..............................
# compute first alignment with guide tree
# +++++++++++++++++++++++++++++
# first alignment score : 732854.1
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 732854.1
# ....................+........+..................+.........
# refine 2 cut : sum of pairs ========= 1 => 733150.4
# ............................................---------...-.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001313_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001313_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001313.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0001313_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0001290.fasta
# 30	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ..............................
# compute first alignment with guide tree
# +++++++++++++++++++++++++++++
# first alignment score : 1852945.4
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1852945.4
# ...
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003892_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003892.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003892_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003895.fasta
# 30	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ..............................
# compute first alignment with guide tree
# +++++++++++++++++++++++++++++
# first alignment score : 501521.7
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 501521.7
# ......+....++.+................+......+.+++...+...........
# refine 2 cut : sum of pairs ========= 1 => 508655.3
# ....................................-.-----------.........
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003895_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003895_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003895.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003895_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003887.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 1498024.6
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 1498024.6
# ......+...+..++...++.+++.+..++++.++++.++.+.++.++..++....++++
# refine 2 cut : sum of pairs ========= 1 => 1513316.2
# ........+................+...+......++..++..+....+..+.++....
# refine 2 cut : sum of pairs ========= 2 => 1514392.1
# .................+........................+...............+.
# refine 2 cut : sum of pairs ========= 3 => 1514438.1
# .+......+.+.............+............+...+.....+.......+...+
# refine 2 cut : sum of pairs ========= 4 => 1514758.1
# .............................-.........................+....
# refine 2 cut : sum of pairs ========= 5 => 1514791.1
# .............................-......................+......+
# refine 2 cut : sum of pairs ========= 6 => 1515244.1
# +......+......+.........+.+.+++.+++.++++..+.....+.+...++++++
# refine 2 cut : sum of pairs ========= 7 => 1517143.2
# ........+++...+....+..+.........+...+......+...+.+.......+.+
# refine 2 cut : sum of pairs ========= 8 => 1517487.2
# .+............................+.........+...............+..+
# refine 2 cut : sum of pairs ========= 9 => 1517542.2
# +......................+....................................
# refine 2 cut : sum of pairs ========= 10 => 1517552.2
# -.......................------------------------------------
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003887_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003887_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003887.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003887_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003898.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 709348.5
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 709348.5
# ..............................-.........+.........+.........
# refine 2 cut : sum of pairs ========= 1 => 709511.5
# ..............................-..................---------..
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003898_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003898_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003898.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003898_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003896.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 609228.1
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 609228.1
# .+........+..++.+..++..++.....+...++.+..++.+.+++++++....+.++
# refine 2 cut : sum of pairs ========= 1 => 619834.3
# +.................+............++..............+..........+.
# refine 2 cut : sum of pairs ========= 2 => 620941.3
# +.........+...+.............+.......+......+....+......+.+.+
# refine 2 cut : sum of pairs ========= 3 => 621358.3
# .+............+...............+.........+..+.......+........
# refine 2 cut : sum of pairs ========= 4 => 621717.3
# .............................-.............+......+....+...+
# refine 2 cut : sum of pairs ========= 5 => 621998.3
# ...........+................................................
# refine 2 cut : sum of pairs ========= 6 => 622082.3
# -...+........................+...............+..............
# refine 2 cut : sum of pairs ========= 7 => 622159.3
# ...................................-.........--------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003896_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003896_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003896.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003896_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003900.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 426333.2
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 426333.2
# .-..+.+.+..++..+.+..+.++.+..+++++++..++++...+++++++++++.++++
# refine 2 cut : sum of pairs ========= 1 => 438851.7
# .-.................................++.++.......+...+......+.
# refine 2 cut : sum of pairs ========= 2 => 438935.7
# .-...+........................++..............+............+
# refine 2 cut : sum of pairs ========= 3 => 439007.7
# .-.......+...................................+..............
# refine 2 cut : sum of pairs ========= 4 => 439023.8
# .-...........................................--------------.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003900_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003900_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003900.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003900_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003899.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 262598.5
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 262598.5
# ......++.+.++++..+.++..+.....+++++++++++.....+.+++.......+++
# refine 2 cut : sum of pairs ========= 1 => 274448.4
# +........+..+............+................+...++.+....+.....
# refine 2 cut : sum of pairs ========= 2 => 274723.8
# ......+................................................+.+..
# refine 2 cut : sum of pairs ========= 3 => 274753.8
# .........................................+..................
# refine 2 cut : sum of pairs ========= 4 => 274778.8
# -...+.................................................+.....
# refine 2 cut : sum of pairs ========= 5 => 274809.8
# -..................................................-----....
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003899_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003899_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003899.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003899_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003902.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 698087.3
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 698087.3
# +...++....++..+....+++...+...++++...+......++++.+.++......++
# refine 2 cut : sum of pairs ========= 1 => 704136.5
# .+............+..........................+.....+....+....+..
# refine 2 cut : sum of pairs ========= 2 => 704504.8
# .-.............................-.......................-....
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003902_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003902_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003902.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003902_aligned.fasta
# file : /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003903.fasta
# 31	sequences with genetic code	The_Standard_Code
# compute initial pairwise distances
# ...............................
# compute first alignment with guide tree
# ++++++++++++++++++++++++++++++
# first alignment score : 926750.6
#
# start refining the alignment
# refine 2 cut : sum of pairs ========= 0 => 926750.6
# .................+..+++.+.+........++..+....++++..+...+++.++
# refine 2 cut : sum of pairs ========= 1 => 930555.5
# ...+...........................++..+.........+..+...+.+.+...
# refine 2 cut : sum of pairs ========= 2 => 931046.0
# .............................-+........+...........+........
# refine 2 cut : sum of pairs ========= 3 => 931233.7
# .............................-...................--------...
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003903_aligned.fasta' was created.
# The file '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003903_AA.fasta' was created.
# PROGRAM HAS FINISHED SUCCESSFULLY
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003903.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/OG0003903_aligned.fasta
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## To convert the MACSE alignment files to philip format

# %%
from Bio import AlignIO
import os

def convert_fasta_to_phylip(input_path, output_path):
    alignment = AlignIO.read(input_path, "fasta")
    AlignIO.write(alignment, output_path, "phylip-relaxed")

def batch_convert_orthogroups(input_folder, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith("_aligned.fasta"):  # Assuming your MACSE files have this naming pattern
            input_path = os.path.join(input_folder, filename)
            
            # Create the output filename by replacing "_aligned.fasta" with "_aligned.phylip"
            output_filename = filename.replace("_aligned.fasta", "_aligned.phylip")
            output_path = os.path.join(output_folder, output_filename)
            
            # Convert the orthogroup to PHYLIP format
            convert_fasta_to_phylip(input_path, output_path)

# Example usage
orthogroup_folder = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files"
phylip_conversion_folder = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/phylip_conversion"

batch_convert_orthogroups(orthogroup_folder, phylip_conversion_folder)

# %% [markdown]
# ### to generate output in sequential format and not interleaved

# %%
from Bio import AlignIO
import os

def convert_fasta_to_phylip(input_path, output_path):
    alignment = AlignIO.read(input_path, "fasta")
    AlignIO.write(alignment, output_path, "phylip-sequential")

def batch_convert_orthogroups(input_folder, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith("_aligned.fasta"):  # Assuming your MACSE files have this naming pattern
            input_path = os.path.join(input_folder, filename)
            
            # Create the output filename by replacing "_aligned.fasta" with "_aligned.phylip"
            output_filename = filename.replace("_aligned.fasta", "_aligned.phylip")
            output_path = os.path.join(output_folder, output_filename)
            
            # Convert the orthogroup to sequential PHYLIP format
            convert_fasta_to_phylip(input_path, output_path)

# Example usage
orthogroup_folder = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files"
phylip_conversion_folder = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/macse_realignment_files/phylip_conversion_sequential"

batch_convert_orthogroups(orthogroup_folder, phylip_conversion_folder)

# %% [markdown]
# # To switch to PRANK for some OGs that doesnt work with MASCE

# %%
import os
import subprocess
from concurrent.futures import ThreadPoolExecutor

def run_prank(input_path, output_path, prank_executable):
    # Run PRANK using subprocess
    prank_cmd = [
        prank_executable,
        '-d=' + input_path,
        '-o=' + output_path,
    ]

    try:
        result = subprocess.run(prank_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True, text=True)
        print(result.stdout)
        print(result.stderr)

        print(f"Alignment for {input_path} completed. Output saved to {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Error during alignment for {input_path}. Details:\n{e}")

def convert_to_phylip(input_path, output_path):
    # PRANK output can be specified to be in PHYLIP format directly during the alignment
    print(f"Conversion of {input_path} to PHYLIP format is not needed as PRANK can output PHYLIP format directly.")

def align_and_convert_parallel(orthogroup_folder, output_folder, num_threads, prank_executable):
    # Get a list of input FASTA files (one per orthogroup)
    input_files = [f for f in os.listdir(orthogroup_folder) if f.endswith('.fasta')]
    
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        # Generate a list of (input_path, output_path) tuples
        input_output_paths = [
            (os.path.join(orthogroup_folder, input_file), os.path.join(output_folder, input_file.replace('.fasta', '_aligned')))
            for input_file in input_files
        ]

        # Submit tasks to align sequences
        align_futures = [executor.submit(run_prank, input_path, output_path, prank_executable) for input_path, output_path in input_output_paths]

        # Wait for all alignment tasks to complete
        for future in align_futures:
            future.result()

# Specify the paths and parameters
orthogroup_folder = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file'
output_folder = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files'
num_threads = 4  # Adjust the number of threads based on your system's capabilities

# Specify the full path to the PRANK executable
prank_executable = '/usr2/people/shollyt22/.conda/envs/prank/bin/prank'  # Update with your actual path

# Run the alignment script
align_and_convert_parallel(orthogroup_folder, output_folder, num_threads, prank_executable)

# %% [markdown]
# ## to generate output in sequential format and not interleaved

# %%
from Bio import AlignIO
import os

def convert_fasta_to_phylip(input_path, output_path):
    alignment = AlignIO.read(input_path, "fasta")
    AlignIO.write(alignment, output_path, "phylip-sequential")

def batch_convert_orthogroups(input_folder, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith("_aligned.best.fas"):  # Assuming your MACSE files have this naming pattern
            input_path = os.path.join(input_folder, filename)
            
            # Create the output filename by replacing "_aligned.fasta" with "_aligned.phylip"
            output_filename = filename.replace("_aligned.best.fas", "_aligned.phylip")
            output_path = os.path.join(output_folder, output_filename)
            
            # Convert the orthogroup to sequential PHYLIP format
            convert_fasta_to_phylip(input_path, output_path)

# Example usage
orthogroup_folder = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files"
phylip_conversion_folder = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/phylip_conversion_sequential"

batch_convert_orthogroups(orthogroup_folder, phylip_conversion_folder)
