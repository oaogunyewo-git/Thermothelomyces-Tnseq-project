# %%
import os

my_genelist = ['OG0003058.fasta', 'OG0003059.fasta', 'OG0003060.fasta', 'OG0003061.fasta', 'OG0003062.fasta']

for myfasta_name in my_genelist:
    # strip out OG name from mygene
    ret = myfasta_name.split('.fasta')
    myorthogroup_name = ret[0]

    inputline_1 = (
        '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/'
        + myorthogroup_name + '.fasta' + ' '
        + '-physout' + ' '
        + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/'
        + myorthogroup_name + 'msf' + '\n'
        + '-clwout' + ' '
        + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/'
        + myorthogroup_name + 'aln' + '\n'
    )

    f = open('firstline.fasta', 'a')
    f.write(inputline_1)
    f.close()

    my_new_string = 'muscle -in ' + inputline_1
    print(my_new_string)
    os.system(my_new_string)
# Out:
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003058.fasta -physout /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/OG0003058msf
# -clwout /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/OG0003058aln
#
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003059.fasta -physout /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/OG0003059msf
# -clwout /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/OG0003059aln
#
# ...

# %%
import os

my_genelist = ['OG0003058.fasta', 'OG0003059.fasta', 'OG0003060.fasta', 'OG0003061.fasta', 'OG0003062.fasta']

for myfasta_name in my_genelist:
    # strip out OG name from mygene
    ret = myfasta_name.split('.fasta')
    myorthogroup_name = ret[0]

    inputline_1 = (
        '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/'
        + myorthogroup_name + '.fasta' + ' '
        + '-physout' + ' '
        + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/alignment_aln/'
        + myorthogroup_name + 'msf'
    )

    f = open('firstline.fasta', 'a')
    f.write(inputline_1 + '\n')  # Add a newline character here
    f.close()

    my_new_string = 'muscle -in firstline.fasta'  # Pass the file as input to muscle
    print(my_new_string)
    os.system(my_new_string)
# Out:
# muscle -in firstline.fasta
# muscle -in firstline.fasta
# muscle -in firstline.fasta
# muscle -in firstline.fasta
# muscle -in firstline.fasta
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
