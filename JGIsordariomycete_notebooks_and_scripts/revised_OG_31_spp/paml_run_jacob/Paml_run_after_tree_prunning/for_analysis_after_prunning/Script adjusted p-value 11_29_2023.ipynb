# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /auto/sahara/namib/home/shollyt22/anaconda3/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /auto/sahara/namib/home/shollyt22/anaconda3/lib/python3.9/site-packages (from scipy) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from statsmodels.stats import multitest

# Read orthogroups and p-values from a CSV file
input_filename = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/paml_run_jacob/Paml_run_after_tree_prunning/for_analysis_after_prunning/final_output_p_values_11_29_2023_filtered_1.csv'
output_filename = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/paml_run_jacob/Paml_run_after_tree_prunning/for_analysis_after_prunning/final_output_adjusted_p_values_11_29_2023_filtered.csv'
print(input_filename)
orthogroups = []
p_values = []

with open(input_filename, 'r') as csvfile:
    reader = csv.reader(csvfile)
    header = next(reader)  # Read the header row
    for row in reader:
        orthogroup, p_value = row
        orthogroups.append(orthogroup)
        p_values.append(float(p_value))

# Calculate adjusted p-values using the Benjamini-Hochberg (FDR) correction
adjusted_p_values = multitest.fdrcorrection(p_values)[1]

# Save the orthogroups, original p-values, and their corresponding adjusted p-values to a CSV file
with open(output_filename, 'w', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(['Orthogroup', 'Original P-value', 'Adjusted P-value'])
    for orthogroup, orig_p, adj_p in zip(orthogroups, p_values, adjusted_p_values):
        writer.writerow([orthogroup, orig_p, adj_p])

print(f"Adjusted p-values saved to {output_filename}")
# Out:
# /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/paml_run_jacob/Paml_run_after_tree_prunning/for_analysis_after_prunning/final_output_p_values_11_29_2023_filtered_1.csv
# Adjusted p-values saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/paml_run_jacob/Paml_run_after_tree_prunning/for_analysis_after_prunning/final_output_adjusted_p_values_11_29_2023_filtered.csv
