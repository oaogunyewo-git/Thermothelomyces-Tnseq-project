# %%
import sys
import csv
import os
from scipy.stats import chi2
import numpy as np
from statsmodels.stats.multitest import multipletests  # Import multipletests from statsmodels

# Read orthogroups and p-values from a CSV file
filename = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/paml_run_jacob/for_analysis/final_output_10_12_2023.csv'
print(filename)

orthogroups = []
p_values = []

with open(filename, 'r') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header row if present
    for row in reader:
        orthogroup, p_value = row
        orthogroups.append(orthogroup)
        p_values.append(float(p_value))

# Calculate adjusted p-values using the Benjamini-Hochberg (FDR) correction
adjusted_p_values = sm.stats.multitest.multipletests(pvals=p_values, method='fdr_bh')[1]

# Print the orthogroups, original p-values, and their corresponding adjusted p-values
for orthogroup, orig_p, adj_p in zip(orthogroups, p_values, adjusted_p_values):
    print(f'Orthogroup: {orthogroup}\tOriginal p-value: {orig_p:.4f}\tAdjusted p-value: {adj_p:.4f}')
