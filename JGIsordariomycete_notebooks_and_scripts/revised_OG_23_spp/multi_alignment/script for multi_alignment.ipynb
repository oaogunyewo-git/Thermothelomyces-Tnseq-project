# %%
pip install muscle
# Out:
# ...
#   Using cached muscle-0.0.4-py3-none-any.whl (3.8 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import subprocess as sp

# %%
file = open('/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_orthogroups/multi_alignment/my_orthogroups_name_file')
lines = file.readlines ()
#print(lines)

# %%
for myfasta_name in lines:
        # strip out OG name from mygene
    ret = myfasta_name.split('.fasta')
    myorthogroup_name = ret[0]
    inputline_1 = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_orthogroups/written_OG_nucl' + myorthogroup_name + '.fasta' + ' ' + '-fastaout' + ' ' + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_orthogroups/' + myorthogroup_name + '.afa' + ' ' + '-clwout' + ' ' + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_orthogroups/' + myorthogroup_name + 'aln' + ' ' + '-physout' + ' ' + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_orthogroups/' + myorthogroup_name + 'msf' + '\n'
    f = open('firstline.fasta','a')
    f.write(inputline_1)
    f.close()
    my_new_string = 'muscle -in ' + inputline_1
    #print(my_new_string)
    os.system(my_new_string)
# Out:
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# sh: muscle: command not found
# ...
