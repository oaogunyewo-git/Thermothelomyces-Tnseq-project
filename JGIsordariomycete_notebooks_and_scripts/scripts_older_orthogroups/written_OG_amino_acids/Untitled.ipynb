# %%
import os
import sys
import subprocess as sp

# %%
file = open('/usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/my_orthogroups_name_file')
lines = file.readlines ()

# %%
for myfasta_name in lines:		 	
	#os.system('rm firstline_nul.ctl')
    #os.system('rm lastline_nul.ctl')
    #strip out OG name from mygene
    ret = myfasta_name.split('.fasta')
    myorthogroup_name = ret[0]
    #print(myorthogroup_name)
    inputline_1 = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/aa_fasta_files/' + myorthogroup_name + '.fasta' + ' ' + '-phys' + ' ' + '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/' + myorthogroup_name + '.fasta' + '\n'
    f = open('firstline.fasta','a')
    f.write(inputline_1)
    f.close()
    my_new_string = 'muscle -in ' + inputline_1
    print(my_new_string)
    os.system(my_new_string)
# Out:
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/aa_fasta_files/OG0003058.fasta -phys /usr2/people/shollyt22/shollyt22/JGIsordariomycete/OG0003058.fasta
#
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/aa_fasta_files/OG0003059.fasta -phys /usr2/people/shollyt22/shollyt22/JGIsordariomycete/OG0003059.fasta
#
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/aa_fasta_files/OG0003060.fasta -phys /usr2/people/shollyt22/shollyt22/JGIsordariomycete/OG0003060.fasta
#
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/aa_fasta_files/OG0003061.fasta -phys /usr2/people/shollyt22/shollyt22/JGIsordariomycete/OG0003061.fasta
#
# muscle -in /usr2/people/shollyt22/shollyt22/JGIsordariomycete/written_OG_amino_acids/aa_fasta_files/OG0003062.fasta -phys /usr2/people/shollyt22/shollyt22/JGIsordariomycete/OG0003062.fasta
#
# ...
