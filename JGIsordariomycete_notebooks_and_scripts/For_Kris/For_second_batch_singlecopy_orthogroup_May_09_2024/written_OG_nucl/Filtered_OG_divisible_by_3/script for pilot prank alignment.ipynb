# %%
import os
import subprocess
from concurrent.futures import ThreadPoolExecutor

def run_prank(input_path, output_path, prank_executable):
    # Run PRANK using subprocess
    prank_cmd = [
        prank_executable,
        '-d=' + input_path,
        '-o=' + output_path,
    ]

    try:
        result = subprocess.run(prank_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True, text=True)
        print(result.stdout)
        print(result.stderr)

        print(f"Alignment for {input_path} completed. Output saved to {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"Error during alignment for {input_path}. Details:\n{e}")

def convert_to_phylip(input_path, output_path):
    # PRANK output can be specified to be in PHYLIP format directly during the alignment
    print(f"Conversion of {input_path} to PHYLIP format is not needed as PRANK can output PHYLIP format directly.")

def align_and_convert_parallel(orthogroup_folder, output_folder, num_threads, prank_executable):
    # Get a list of input FASTA files (one per orthogroup)
    input_files = [f for f in os.listdir(orthogroup_folder) if f.endswith('.fasta')]
    
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        # Generate a list of (input_path, output_path) tuples
        input_output_paths = [
            (os.path.join(orthogroup_folder, input_file), os.path.join(output_folder, input_file.replace('.fasta', '_aligned')))
            for input_file in input_files
        ]

        # Submit tasks to align sequences
        align_futures = [executor.submit(run_prank, input_path, output_path, prank_executable) for input_path, output_path in input_output_paths]

        # Wait for all alignment tasks to complete
        for future in align_futures:
            future.result()

# Specify the paths and parameters
orthogroup_folder = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2'
output_folder = '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files'
num_threads = 4  # Adjust the number of threads based on your system's capabilities

# Specify the full path to the PRANK executable
prank_executable = '/usr2/people/shollyt22/.conda/envs/prank/bin/prank'  # Update with your actual path

# Run the alignment script
align_and_convert_parallel(orthogroup_folder, output_folder, num_threads, prank_executable)
# Out:
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005174.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 1718
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 1629
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 1629
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 1629
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 1629
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005174_aligned.best.fas'
#
# Analysis done. Total time 35s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005174.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005174_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005204.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 40535
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 34878
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 36478
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 33909
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 37859
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005204_aligned.best.fas'
#
# Analysis done. Total time 1645s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005204.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005204_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005183.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 31706
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 31664
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 33309
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 33397
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 33263
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005183_aligned.best.fas'
#
# Analysis done. Total time 1713s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005183.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005183_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005165.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 33150
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 29556
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 31429
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 30881
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 29759
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005165_aligned.best.fas'
#
# Analysis done. Total time 1937s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005165.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005165_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005207.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 32311
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 35366
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 35417
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 36117
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 38328
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005207_aligned.best.fas'
#
# Analysis done. Total time 2198s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005207.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005207_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005246.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 15160
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 14624
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 15012
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 14881
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 15012
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005246_aligned.best.fas'
#
# Analysis done. Total time 1110s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005246.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005246_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005277.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 3003
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 3100
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 3100
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 3100
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 3100
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005277_aligned.best.fas'
#
# Analysis done. Total time 63s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005277.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005277_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005233.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 19599
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 19143
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 19135
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 19151
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 19151
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005233_aligned.best.fas'
#
# Analysis done. Total time 1492s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005233.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005233_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005274.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 29664
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 30322
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 26984
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 29700
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 29243
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005274_aligned.best.fas'
#
# Analysis done. Total time 904s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005274.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005274_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005376.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 8605
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 8322
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 8497
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 8497
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 8497
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005376_aligned.best.fas'
#
# Analysis done. Total time 311s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005376.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005376_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005363.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 39056
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 39188
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 36340
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 34974
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 39508
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005363_aligned.best.fas'
#
# Analysis done. Total time 931s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005363.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005363_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005389.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 43427
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 46606
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 46255
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 48466
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 45207
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005389_aligned.best.fas'
#
# Analysis done. Total time 1405s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005389.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005389_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005523.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 38716
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 37462
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 37121
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 36216
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 41764
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005523_aligned.best.fas'
#
# Analysis done. Total time 1506s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005523.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005523_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005533.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 24923
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 24796
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 23265
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 23456
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 24707
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005533_aligned.best.fas'
#
# Analysis done. Total time 1107s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005533.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005533_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005543.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 16601
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 17541
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 17102
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 17334
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 17190
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005543_aligned.best.fas'
#
# Analysis done. Total time 1530s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005543.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005543_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005587.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 30132
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 30150
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 31945
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 32914
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 33182
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005587_aligned.best.fas'
#
# Analysis done. Total time 889s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005587.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005587_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005616.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 4112
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 3748
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 4130
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 3990
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 3995
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005616_aligned.best.fas'
#
# Analysis done. Total time 75s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005616.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005616_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005693.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 25963
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 24853
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 24987
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 25779
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 25781
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005693_aligned.best.fas'
#
# Analysis done. Total time 1053s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005693.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005693_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005737.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 12546
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 14375
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 13613
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 13618
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 13631
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005737_aligned.best.fas'
#
# Analysis done. Total time 210s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005737.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005737_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005524.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 63204
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 66700
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 66840
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 67446
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 67683
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005524_aligned.best.fas'
#
# Analysis done. Total time 4556s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005524.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005524_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005671.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 43796
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 41047
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 43982
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 44691
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 44641
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005671_aligned.best.fas'
#
# Analysis done. Total time 2874s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005671.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005671_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005818.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 13568
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 13913
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 14504
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 14999
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 15249
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005818_aligned.best.fas'
#
# Analysis done. Total time 220s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005818.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005818_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005269.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 71653
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 73968
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 73133
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 76245
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 73555
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005269_aligned.best.fas'
#
# Analysis done. Total time 7695s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005269.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005269_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005750.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 27357
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 27404
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 27822
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 27340
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 27921
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005750_aligned.best.fas'
#
# Analysis done. Total time 1928s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005750.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005750_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005969.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 11615
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 11710
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 11801
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 11519
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 11321
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005969_aligned.best.fas'
#
# Analysis done. Total time 236s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005969.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005969_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006055.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 10234
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 10472
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 10355
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 10630
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 9943
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006055_aligned.best.fas'
#
# Analysis done. Total time 235s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006055.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006055_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005921.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 26376
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 28356
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 27694
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 26403
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 27017
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005921_aligned.best.fas'
#
# Analysis done. Total time 488s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005921.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005921_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006007.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 21218
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 19458
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 21331
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 19081
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 18677
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006007_aligned.best.fas'
#
# Analysis done. Total time 988s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006007.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006007_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006242.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 17439
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 18158
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 16500
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 17450
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 16748
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006242_aligned.best.fas'
#
# Analysis done. Total time 793s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006242.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006242_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006222.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 27698
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 26507
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 28355
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 26169
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 25675
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006222_aligned.best.fas'
#
# Analysis done. Total time 831s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006222.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006222_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006375.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 26145
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 23466
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 21609
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 21772
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 21508
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006375_aligned.best.fas'
#
# Analysis done. Total time 469s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006375.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006375_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006586.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 6175
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 5890
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 5883
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 5883
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 5883
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006586_aligned.best.fas'
#
# Analysis done. Total time 128s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006586.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006586_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005755.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 39816
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 37805
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 41770
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 40305
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 39178
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005755_aligned.best.fas'
#
# Analysis done. Total time 3275s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0005755.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0005755_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006380.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 19374
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 18577
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 18613
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 18570
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 18613
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006380_aligned.best.fas'
#
# Analysis done. Total time 738s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006380.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006380_aligned
# -----------------
#  PRANK v.170427:
# -----------------
#
# Input for the analysis
#  - aligning sequences in '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006540.fasta'
#  - using inferred alignment guide tree
#  - option '+F' is not used; it can be enabled with '+F'
#
# Generating approximate guide tree.
# Correcting (arbitrarily) for multifurcating nodes.
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 1.
#
# Alignment score: 63075
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 2.
#
# Alignment score: 57376
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 3.
#
# Alignment score: 58280
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 4.
#
# Alignment score: 54787
# Correcting (arbitrarily) for multifurcating nodes.
#
# Generating multiple alignment: iteration 5.
#
# Alignment score: 57636
#
#
# Writing
#  - alignment to '/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006540_aligned.best.fas'
#
# Analysis done. Total time 3353s
#
#
#
# Alignment for /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/short_prank_fasta_file/Batch_2/OG0006540.fasta completed. Output saved to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3/prank_realignment_files/OG0006540_aligned
