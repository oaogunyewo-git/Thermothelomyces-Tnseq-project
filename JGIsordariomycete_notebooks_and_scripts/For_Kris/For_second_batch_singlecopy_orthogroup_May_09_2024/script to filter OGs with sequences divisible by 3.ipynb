# %%
import os

def read_fasta_file(file_path):
    sequences = {}
    current_seq = ""
    with open(file_path, "r") as fasta_file:
        for line in fasta_file:
            line = line.strip()
            if line.startswith(">"):
                if current_seq:
                    sequences[header] = current_seq
                header = line[1:]
                current_seq = ""
            else:
                current_seq += line
        if current_seq:  # Add the last sequence
            sequences[header] = current_seq
    return sequences

def is_divisible_by_three(sequence):
    return len(sequence) % 3 == 0

# Replace this with the directory where your orthogroup FASTA files are located
orthogroup_directory = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/OG_nucl"

# Output directory for filtered sequences
output_directory = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files"

orthogroup_files = [os.path.join(orthogroup_directory, file) for file in os.listdir(orthogroup_directory) if file.endswith(".fasta")]

for orthogroup_file in orthogroup_files:
    print(f"Processing file: {orthogroup_file}")
    sequences = read_fasta_file(orthogroup_file)
    
    filtered_sequences = {}

    for header, sequence in sequences.items():
        if is_divisible_by_three(sequence):
            filtered_sequences[header] = sequence

    if not filtered_sequences:
        print("No sequences divisible by three in this orthogroup.")
    else:
        output_file = os.path.join(output_directory, os.path.basename(orthogroup_file))
        with open(output_file, "w") as output_fasta:
            for header, sequence in filtered_sequences.items():
                output_fasta.write(f">{header}\n{sequence}\n")
        print(f"Filtered sequences written to {output_file}")
# Out:
# Processing file: /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/OG_nucl/OG0003058.fasta
# Filtered sequences written to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003058.fasta
# Processing file: /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/OG_nucl/OG0003059.fasta
# Filtered sequences written to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003059.fasta
# Processing file: /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/OG_nucl/OG0003060.fasta
# Filtered sequences written to /usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3/fasta_files/OG0003060.fasta
# ...

# %%
import os

def read_fasta_file(file_path):
    sequences = {}
    current_seq = ""
    with open(file_path, "r") as fasta_file:
        for line in fasta_file:
            line = line.strip()
            if line.startswith(">"):
                if current_seq:
                    sequences[header] = current_seq
                header = line[1:]
                current_seq = ""
            else:
                current_seq += line
        if current_seq:  # Add the last sequence
            sequences[header] = current_seq
    return sequences

def is_divisible_by_three(sequence):
    return len(sequence) % 3 == 0

# Replace this with the directory where your orthogroup FASTA files are located
orthogroup_directory = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/OG_nucl"

# Output directory for filtered sequences
output_directory = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/revised_OG_31_spp/written_OG_nucl/Filtered_OG_divisible_by_3_count"

orthogroup_files = [os.path.join(orthogroup_directory, file) for file in os.listdir(orthogroup_directory) if file.endswith(".fasta")]

for orthogroup_file in orthogroup_files:
    print(f"Processing file: {orthogroup_file}")
    sequences = read_fasta_file(orthogroup_file)
    
    filtered_sequences = {}
    for header, sequence in sequences.items():
        if is_divisible_by_three(sequence):
            filtered_sequences[header] = sequence

    if filtered_sequences:
        # Count the number of species in the orthogroup after filtering
        species_count = len(set(header.split('_')[0] for header in filtered_sequences.keys()))

        print(f"Number of species in filtered orthogroup: {species_count}")

        # Write the orthogroup to a new file if it contains filtered sequences
        output_file = os.path.join(output_directory, os.path.basename(orthogroup_file))
        with open(output_file, "w") as output_fasta:
            for header, sequence in filtered_sequences.items():
                output_fasta.write(f">{header}\n{sequence}\n")
        #print(f"Filtered sequences written to {output_file}")
        # Print lengths of sequences for troubleshooting
        for header, sequence in filtered_sequences.items():
            print(f"Length of sequence {header}: {len(sequence)}")

        # Print sequences for troubleshooting
        #for header, sequence in filtered_sequences.items():
            #print(f"Sequence {header}: {repr(sequence)}")
    else:
        print("No sequences divisible by three in this orthogroup.")

# %% [markdown]
# ## To analyse with the more single copies found out

# %%
import os

def read_fasta_file(file_path):
    sequences = {}
    current_seq = ""
    with open(file_path, "r") as fasta_file:
        for line in fasta_file:
            line = line.strip()
            if line.startswith(">"):
                if current_seq:
                    sequences[header] = current_seq
                header = line[1:]
                current_seq = ""
            else:
                current_seq += line
        if current_seq:  # Add the last sequence
            sequences[header] = current_seq
    return sequences

def is_divisible_by_three(sequence):
    return len(sequence) % 3 == 0

# Replace this with the directory where your orthogroup FASTA files are located
orthogroup_directory = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/OG_nucl/"

# Output directory for filtered sequences
output_directory = "/usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/Filtered_OG_divisible_by_3"

orthogroup_files = [os.path.join(orthogroup_directory, file) for file in os.listdir(orthogroup_directory) if file.endswith(".fasta")]

for orthogroup_file in orthogroup_files:
    print(f"Processing file: {orthogroup_file}")
    sequences = read_fasta_file(orthogroup_file)
    
    filtered_sequences = {}
    for header, sequence in sequences.items():
        if is_divisible_by_three(sequence):
            filtered_sequences[header] = sequence

    if filtered_sequences:
        # Count the number of species in the orthogroup after filtering
        species_count = len(set(header.split('_')[0] for header in filtered_sequences.keys()))

        print(f"Number of species in filtered orthogroup: {species_count}")

        # Write the orthogroup to a new file if it contains filtered sequences
        output_file = os.path.join(output_directory, os.path.basename(orthogroup_file))
        with open(output_file, "w") as output_fasta:
            for header, sequence in filtered_sequences.items():
                output_fasta.write(f">{header}\n{sequence}\n")
        #print(f"Filtered sequences written to {output_file}")
        # Print lengths of sequences for troubleshooting
        for header, sequence in filtered_sequences.items():
            print(f"Length of sequence {header}: {len(sequence)}")

        # Print sequences for troubleshooting
        #for header, sequence in filtered_sequences.items():
            #print(f"Sequence {header}: {repr(sequence)}")
    else:
        print("No sequences divisible by three in this orthogroup.")
# Out:
# Processing file: /usr2/people/shollyt22/shollyt22/JGIsordariomycete/For_second_batch_singlecopy_orthogroup_May_09_2024/written_OG_nucl/OG_nucl/OG0000683.fasta
# Number of species in filtered orthogroup: 31
# Length of sequence podbul: 2724
# Length of sequence arnari: 2691
# Length of sequence podbac: 2706
# Length of sequence podset: 2730
# Length of sequence podcom: 2706
# Length of sequence podans: 2706
# Length of sequence podbel: 2703
# Length of sequence podpse: 2703
# Length of sequence canare: 2661
# Length of sequence madmyc: 2664
# Length of sequence chathe: 2634
# Length of sequence triant: 2688
# Length of sequence theter: 2679
# Length of sequence achmac: 2673
# Length of sequence achstr: 2550
# Length of sequence stalon: 2679
# Length of sequence mycthe: 2664
# Length of sequence parapp: 2661
# Length of sequence parhyr: 2664
# Length of sequence chalep: 3483
# Length of sequence dicfun: 2664
# Length of sequence corina: 2655
# Length of sequence chacoc: 2655
# ...
