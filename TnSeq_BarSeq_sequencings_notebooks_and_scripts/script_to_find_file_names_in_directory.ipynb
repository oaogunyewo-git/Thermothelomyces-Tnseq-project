# %%
# !find ~ -iname "all_batches_together_06_12_2024_merged.fastq"
# Out:
# ^C

# %%
# !find /usr2/people/shollyt22 -iname "all_batches_together_06_12_2024_merged.fastq"
# Out:
# ^C

# %%
# !find /usr2/people/shollyt22/shollyt22 -iname "*merged.fastq" 2>/dev/null
# Out:
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/TnSeq_Results_may_2023/Barseq_M003594/OORB003_S1_L001_merged.fastq
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Barseq_July_2023/OORB003_TnSeq/for_analysis/TNSeq_merge_FASTQ/OORB003_S1_L001_merged.fastq
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Barseq_July_2023/OORB003_TnSeq/OORB003_S1_L001_merged.fastq
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/Tnseq_fastq_files_jumpstart_polymerase/TNSeq_merge_FASTQ/fastq_file_for_two_sequencing_batches_merged.fastq
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/Tnseq_fastq_files_Q5_polymerase/TNSeq_merge_FASTQ/OORB027_S1_L001_merged.fastq
# ...

# %%
# !grep -Rin "merge_fastq(files_to_merge" /usr2/people/shollyt22/shollyt22 --include="*.py" --include="*.ipynb" 2>/dev/null
# Out:
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/digestion_time_optimization_June_07_2024/to_merge_multiple_fastq.ipynb:135:    "merge_fastq(files_to_merge, '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/TNSeq_merge_FASTQ/all_digestion_time_merged.fastq')"
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/script_to_check_if_sequences_overlap.ipynb:260:    "merge_fastq(files_to_merge, '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/all_available_fastq_merged/all_batches_together_06_12_2024_merged.fastq')\n"
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Untitled.ipynb:79:    "!grep -Rin \"merge_fastq(files_to_merge\" /usr2/people/shollyt22/shollyt22 --include=\"*.py\" --include=\"*.ipynb\" 2>/dev/null\n"
