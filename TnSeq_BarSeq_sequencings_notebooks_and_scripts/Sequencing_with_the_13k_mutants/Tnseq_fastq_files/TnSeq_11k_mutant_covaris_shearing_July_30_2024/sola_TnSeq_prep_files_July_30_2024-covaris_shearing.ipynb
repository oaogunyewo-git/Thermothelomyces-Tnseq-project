# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /auto/sahara/namib/home/shollyt22/.conda/envs/jupyter/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: tzdata>=2022.1 in /auto/sahara/namib/home/shollyt22/.conda/envs/jupyter/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /auto/sahara/namib/home/shollyt22/.conda/envs/jupyter/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /auto/sahara/namib/home/shollyt22/.conda/envs/jupyter/lib/python3.10/site-packages (from pandas) (1.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /auto/sahara/namib/home/shollyt22/.conda/envs/jupyter/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /auto/sahara/namib/home/shollyt22/.conda/envs/jupyter/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt



#makes viewing pandas tables better
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# ## Download TNseq data

# %%
#change this to where your FASTQs are

FASTQ_directory = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024'

# %% [raw]
# How big is each FASTQ file?

# %%
fastq_files = !ls {FASTQ_directory}/*.fastq.gz

for f in fastq_files:

    size = !du -sh {f}
    size = size[0].split('\t')[0]
    
    print('{}: {}'.format(f, size))
# Out:
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R1_001.fastq.gz: 153M
# /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R2_001.fastq.gz: 167M

# %% [markdown]
# ## Merge paired end reads
#
# This step combines the forward and reverse mate pairs from two fastq files.

# %% [raw]
# Get list of TNseq fastq.gz sequencing files. We only need one file (R1) from each pair (R1, R2) because they have the same prefix (the file name before _R1_001 and _R2_001).

# %%
#check that these are the files you want - if not, set the fastq list to the correct list of paths by hand
#eg: fastqs = ['correctfile1_R1_001.fastq.gz', correctfile2_R1_001.fastq.gz]

fastqs = !ls {FASTQ_directory}/*R1_001.fastq.gz
fastqs
# Out:
# ['/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R1_001.fastq.gz']

# %% [raw]
# We're using Melanie's install of bbmerge and nice -n 17 to put our code at the lowest priority on the server (it takes a lot of power and time and we want to be "nice" to other users). The code below takes ~20 minutes per 4Gb fastq file, will take longer if the files are bigger! There is useful information about the number of paired reads in the output below.

# %%
# !mkdir /usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/TNSeq_merge_FASTQ

# %%
for fastq in fastqs:
    
    fastq_prefix = fastq.replace('_R1_001.fastq.gz', '')
    output_prefix = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/TNSeq_merge_FASTQ/{}'.format(fastq_prefix.split('/')[-1])
    
    cmd = "nice -n 17 /usr2/people/mabrams/bin/bbmap/bbmerge.sh in1={}_R1_001.fastq.gz in2={}_R2_001.fastq.gz out={}_merged.fastq ihist={}_hist.txt".format(fastq_prefix,
                                                                                                          fastq_prefix,
                                                                                                          output_prefix,
                                                                                                          output_prefix)
    # !{cmd}
# Out:
# java -ea -Xmx1000m -Xms1000m -Djava.library.path=/usr2/people/mabrams/bin/bbmap/jni/ -cp /usr2/people/mabrams/bin/bbmap/current/ jgi.BBMerge in1=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R1_001.fastq.gz in2=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R2_001.fastq.gz out=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/TNSeq_merge_FASTQ/OORB031_S1_L001_merged.fastq ihist=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/TNSeq_merge_FASTQ/OORB031_S1_L001_hist.txt
# Executing jgi.BBMerge [in1=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R1_001.fastq.gz, in2=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/OORB031_S1_L001_R2_001.fastq.gz, out=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/TNSeq_merge_FASTQ/OORB031_S1_L001_merged.fastq, ihist=/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_mutant_covaris_shearing_July_30_2024/TNSeq_merge_FASTQ/OORB031_S1_L001_hist.txt]
# Version 38.61
#
# Writing mergable reads merged.
# Started output threads.
# Total time: 17.651 seconds.
#
# Pairs:               	1718952
# Joined:              	1209279   	70.350%
# Ambiguous:           	497982   	28.970%
# No Solution:         	11691   	0.680%
# Too Short:           	0       	0.000%
#
# Avg Insert:          	93.0
# Standard Deviation:  	37.6
# Mode:                	73
#
# Insert range:        	35 - 291
# 90th percentile:     	138
# 75th percentile:     	111
# 50th percentile:     	88
# 25th percentile:     	68
# 10th percentile:     	51

# %%
#plot output histograms of insert size vs. count

histogram_files = !ls {FASTQ_directory}/*_hist.txt

for f in histogram_files:
    
    df = pd.read_csv(f, sep='\t', comment='#', header=None)
    df.columns = ['Insert Size', 'Count']
    
    reads = sum(df['Count'])
    
    plt.bar(df['Insert Size'], df['Count'])
    plt.ylabel('Count')
    plt.xlabel('Insert Size')
    plt.title('{}: {} reads'.format(f.split('/')[-1], reads))
    plt.show()

# %% [raw]
# ### Optional: randomly select reads from each FASTQ to create smaller files for testing code
#
# It will take a long time to run the TNseq mapping on the full FASTQ files. For debugging/testing code, it's nice to have small files that are quick to process.

# %%
FASTQ_directory = 'TNSeq_merge_FASTQ'
num_seqs_to_sample = 10000
merged_FASTQs = !ls {FASTQ_directory}/*_merged.fastq

for f in merged_FASTQs:
    
    print(f)
    outfile = f.replace('.fastq', '_subsample.fastq')
    cmd = '/usr2/people/gtl/bin/seqtk/seqtk sample {} {}'.format(f, num_seqs_to_sample)
    
    # !{cmd} > {outfile}
