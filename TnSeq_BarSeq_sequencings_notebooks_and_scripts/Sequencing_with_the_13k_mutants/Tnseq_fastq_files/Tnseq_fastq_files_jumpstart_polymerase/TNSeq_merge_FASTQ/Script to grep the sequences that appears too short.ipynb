# %%
# open the input fastq file and the output file
with open("/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/Tnseq_fastq_files_jumpstart_polymerase/TNSeq_merge_FASTQ/KFRB010_S1_L001_merged-Copy1.fastq", "r") as fastq, open("/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/Tnseq_fastq_files_jumpstart_polymerase/TNSeq_merge_FASTQ/extracted_sequence_5.fastq", "w") as output:
    # flag to determine if we are in a block
    in_block = False
    # read through the fastq file
    for line in fastq:
        # if the line is the target ID, start the block
        if "@M02248:29:000000000-DNTMF:1:1101:12850:4785 1:N:0:ATCACG" in line:
            in_block = True
            # write the ID line
            output.write(line)
        # if in a block, write the following 3 lines
        elif in_block:
            output.write(line)
            # if we have written 3 more lines, end the block
            if line.startswith("+"):
                in_block = False
