# %% [markdown]
# ## To check the number of barcodes against number of genomic mapping in the combined Tnseq poofile

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the annotated data into a DataFrame
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/Batch_2_sequencing_Apr_26_2024/TNSeq_13k_mutants_mapping_output_without_vector_sequence_jumpstart/TNSeq_13k_mutants_mapping_output_jumpstart_polymerase_Apr_30_2024_2_fastq_combined/Tnseq_13k_mutants_04_30_2024_combined_poolfile_annotated_1.csv'
df = pd.read_csv(file_path)

# Count the length of the list in 'All genomic mappings' for each barcode
df['MappingCount'] = df['All genomic mappings'].apply(lambda x: len(eval(x)) if pd.notnull(x) else 0)

# Plotting the histogram with a log scale on the y-axis
plt.figure(figsize=(12, 6))
df['MappingCount'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black', logy=True)

# Customize the plot
plt.title('Number of Barcodes vs Number of Genomic Mappings')
plt.xlabel('Number of Genomic Mappings')
plt.ylabel('Number of Barcodes (log scale)')
plt.xticks(rotation=0)
plt.grid(axis='y')

# Save the plot as an image file (adjust the filename and format as needed)
#plt.savefig('barcode_vs_genomic_mappings_count.png', bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the annotated data into a DataFrame
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/Batch_2_sequencing_Apr_26_2024/TNSeq_13k_mutants_mapping_output_without_vector_sequence_jumpstart/TNSeq_13k_mutants_mapping_output_jumpstart_polymerase_Apr_30_2024_2_fastq_combined/Tnseq_13k_mutants_04_30_2024_combined_poolfile_annotated_1.csv'
df = pd.read_csv(file_path)

# Count the length of the list in 'All genomic mappings' for each barcode
df['MappingCount'] = df['All genomic mappings'].apply(lambda x: len(eval(x)) if pd.notnull(x) else 0)

# Plotting the histogram
plt.figure(figsize=(12, 6))
df['MappingCount'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the plot
plt.title('Number of Barcodes vs Number of Genomic Mappings')
plt.xlabel('Number of Genomic Mappings')
plt.ylabel('Number of Barcodes')
plt.xticks(rotation=0)
plt.grid(axis='y')

# Save the plot as an image file (adjust the filename and format as needed)
#plt.savefig('barcode_vs_genomic_mappings_count.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### to make histogram for the mapping of the barcode inserts against the location on chromosome

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Tnseq file into a pandas DataFrame
tnseq_data = pd.read_csv("/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/Batch_2_sequencing_Apr_26_2024/TNSeq_13k_mutants_mapping_output_without_vector_sequence_jumpstart/TNSeq_13k_mutants_mapping_output_jumpstart_polymerase_Apr_30_2024_2_fastq_combined/Tnseq_13k_mutants_04_30_2024_combined_poolfile_annotated_1.csv")

# Group the DataFrame by the "scaffold" column and count the number of unique barcodes for each scaffold
scaffold_counts = tnseq_data.groupby('scaffold')['barcode'].nunique()

# Plot the results
plt.figure(figsize=(10, 6))
scaffold_counts.plot(kind='bar')
plt.xlabel('Genomic location')
plt.ylabel('Number of Barcodes')
plt.title('Number of Barcodes per genomic location')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### to change the font size of the previous plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the annotated data into a DataFrame
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/Batch_2_sequencing_Apr_26_2024/TNSeq_13k_mutants_mapping_output_without_vector_sequence_jumpstart/TNSeq_13k_mutants_mapping_output_jumpstart_polymerase_Apr_30_2024_2_fastq_combined/Tnseq_13k_mutants_04_30_2024_combined_poolfile_annotated_1.csv'
df = pd.read_csv(file_path)

# Count the length of the list in 'All genomic mappings' for each barcode
df['MappingCount'] = df['All genomic mappings'].apply(lambda x: len(eval(x)) if pd.notnull(x) else 0)

# Plotting the histogram
plt.figure(figsize=(30, 15))
df['MappingCount'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the plot with font size and type
plt.title('Number of Barcodes vs Number of Genomic Mappings', fontsize=22, fontweight='bold', fontname='Arial')
plt.xlabel('Number of Genomic Mappings', fontsize=20, fontweight='bold', fontname='Arial')
plt.ylabel('Number of Barcodes', fontsize=20, fontweight='bold', fontname='Arial')
plt.xticks(rotation=0, fontsize=20, fontweight='bold', fontname='Arial')
plt.yticks(fontsize=16, fontweight='bold', fontname='Arial')
plt.grid(axis='y')

# Save the plot as an image file (adjust the filename and format as needed)
#plt.savefig('barcode_vs_genomic_mappings_count.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# #### To change the Barseq pool count file from txt to csv for making plots

# %%
import pandas as pd

# Load the data from the TSV file
tsv_file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount.txt'
df = pd.read_csv(tsv_file_path, sep='\t')

# Save the data to a CSV file
csv_file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount.csv'
df.to_csv(csv_file_path, index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the barseq data from the CSV file
csv_file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount.csv'
df_barseq = pd.read_csv(csv_file_path)

# Select the columns for analysis
samples_columns = ['37_A1', '37_A2', '37_B1', '37_B2', '50_A1', '50_A2', '50_B1', '50_B2']

# Calculate the total number of reads per insertion across all samples
df_barseq['TotalReads'] = df_barseq[samples_columns].sum(axis=1)

# Print the head of the 'TotalReads' Series
print(df_barseq['TotalReads'].head())
print(df_barseq['TotalReads'].tail())

# Plotting a histogram of the number of reads per insertion
plt.figure(figsize=(12, 6))
plt.hist(df_barseq['TotalReads'], bins=50, color='skyblue', edgecolor='black', log=True)  # Using log scale on the y-axis

# Customize the plot
plt.title('Histogram of Number of Reads per Insertion (Barseq)')
plt.xlabel('Number of Reads per Insertion')
plt.ylabel('Number of Insertions')
plt.grid(True)

# Set x-axis limits to be less than 2000
#plt.xlim(0, 2000)

# Save the plot as an image file (optional)
#plt.savefig('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Barseq_Temp_study_11_04_2023/histogram_plots/histogram_reads_vs_insertions_barseq.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# 0    144868
# 1     15005
# 2    203566
# 3    245401
# 4    140200
# Name: TotalReads, dtype: int64
# 13359    847
# 13360    407
# 13361      8
# 13362      0
# 13363    109
# Name: TotalReads, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the barseq data from the CSV file
csv_file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount.csv'
df_barseq = pd.read_csv(csv_file_path)

# Select the columns for analysis
samples_columns = ['KFRB007_1', 'KFRB008_1']

# Calculate the total number of reads per insertion across all samples
df_barseq['TotalReads'] = df_barseq[samples_columns].sum(axis=1)

# Print the head of the 'TotalReads' Series
print(df_barseq['TotalReads'].head())
print(df_barseq['TotalReads'].tail())

# Plotting a histogram of the number of reads per insertion
plt.figure(figsize=(12, 6))
plt.hist(df_barseq['TotalReads'], bins=5000, color='skyblue', edgecolor='black', log=True)  # Using log scale on the y-axis

# Customize the plot
plt.title('Histogram of Number of Reads per Insertion (Barseq)')
plt.xlabel('Number of Reads per Insertion')
plt.ylabel('Number of Insertions')
plt.grid(True)

# Set x-axis limits to be less than 2000
plt.xlim(0, 5000)

# Save the plot as an image file (optional)
#plt.savefig('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Barseq_Temp_study_11_04_2023/histogram_plots/histogram_reads_vs_insertions_barseq_shorter.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 12
#       9 samples_columns = ['KFRB007_1', 'KFRB008_1']
#      11 # Calculate the total number of reads per insertion across all samples
# ---> 12 df_barseq['TotalReads'] = df_barseq[samples_columns].sum(axis=1)
#      14 # Print the head of the 'TotalReads' Series
#      15 print(df_barseq['TotalReads'].head())
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %% [markdown]
# # to make histograms plots of reads per insert and inserts per gene for barseq

# %% [markdown]
# ### for reads per insert

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Barseq pool count file into a DataFrame
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount.txt'
df = pd.read_csv(file_path, sep='\t')

# Calculate the sum of reads per insert
df['total_reads'] = df.iloc[:, 4:].sum(axis=1)

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(df['total_reads'], bins=500, color='blue', edgecolor='black')
plt.title('Histogram for number of Reads per Insert')
plt.xlabel('Total Reads')
plt.ylabel('Frequency')
plt.xlim(0, 80000)  # Adjust the range for the x-axis
plt.ylim(0, 20000)  # Adjust the range for the y-axis
plt.grid(True)
#plt.savefig('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Barseq_Temp_study_11_04_2023/histogram_plots/barseq_number_of_reads_per_inserts.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### for inserts per gene

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the Barseq pool count file into a DataFrame
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount.txt'
df = pd.read_csv(file_path, sep='\t')

# Ensure all chromosome values are strings
df['scaffold'] = df['scaffold'].astype(str)
df['chromosome'] = df['scaffold'].str.extract(r'(chr\d+)', expand=False)

# Check that the 'position' column is correct and ensure it's numeric
df['position'] = pd.to_numeric(df['pos'], errors='coerce')  # Adjust to the correct column name for genomic position
df.dropna(subset=['position'], inplace=True)  # Remove rows with invalid 'position'

# Chromosome sizes dictionary
chromosome_sizes = {
    'chr1': 10931058,
    'chr2': 5454242,
    'chr3': 5062665,
    'chr4': 4710208,
    'chr5': 4342007,
    'chr6': 4127677,
    'chr7': 4116359,
}

# Define bin size (10,000 base pairs)
bin_size = 50000  # Set bin size to desired value

# Create bins for the position within each chromosome
df['bin'] = (df['position'] // bin_size) * bin_size

# Ensure the chromosome column is a string
df['chromosome'] = df['chromosome'].astype(str)

# Group by chromosome and bin to count inserts
inserts_per_chromosome_bin = df.groupby(['chromosome', 'bin'])['barcode'].count().reset_index()

# Function to extract the numerical part of the chromosome for sorting
def extract_numeric_chromosome(chromosome):
    if isinstance(chromosome, str):
        return int(chromosome.replace("chr", ""))
    else:
        return chromosome  # Handle unexpected types gracefully

# Sort chromosomes in correct numerical order
inserts_per_chromosome_bin = inserts_per_chromosome_bin.sort_values(
    by=['chromosome', 'bin'],
    key=lambda x: x.astype(str).map(extract_numeric_chromosome),
    ignore_index=True
)

# Plot the bar plot with bins representing chromosomes and sub-bins based on genomic position
plt.figure(figsize=(15, 8))

# Plot chromosomes sequentially with their respective bin sizes
chromosomes = sorted(chromosome_sizes.keys(), key=extract_numeric_chromosome)
current_offset = 0
bin_width = bin_size * 0.8

chromosome_midpoints = []  # List to store the midpoints for x-ticks

for chromosome in chromosomes:
    if chromosome in inserts_per_chromosome_bin['chromosome'].unique():
        chromosome_data = inserts_per_chromosome_bin[inserts_per_chromosome_bin['chromosome'] == chromosome]
        plt.bar(
            chromosome_data['bin'] + current_offset, 
            chromosome_data['barcode'], 
            width=bin_width, 
            label=chromosome
        )
        # Calculate the midpoint of the current chromosome for x-tick label
        chromosome_midpoint = current_offset + chromosome_sizes[chromosome] / 2
        chromosome_midpoints.append(chromosome_midpoint)
        current_offset += chromosome_sizes[chromosome]

# Add labels and titles with increased font size
plt.title('Total Inserts per Chromosome by Genomic Bins', fontsize=16)
plt.xlabel('Chromosome Position', fontsize=14)
plt.ylabel('Total Inserts', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)

# Set the x-ticks to be at the midpoints of each chromosome with increased font size
plt.xticks(chromosome_midpoints, chromosomes, rotation=45, ha='center', fontsize=12)
plt.yticks(fontsize=12)  # Increase the font size of y-ticks

plt.legend(title='Chromosomes', fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Plots of the individual replicates to check their agreements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
x_column = (df['normalized_37_A1'] + df['normalized_37_A2']) / 2
y_column = (df['normalized_37_B1'] + df['normalized_37_B2']) / 2

# Create a scatter plot using the calculated means
plt.scatter(x_column, y_column, color='black')
plt.xlabel('37A Abundance', fontsize=14)
plt.ylabel('37B Abundance', fontsize=14)
plt.title('Plot of TN insertion abundances at 37°C (Bioreps)', fontsize=16, color='purple')

# Adjust the x and y-axis scale ranges
plt.xlim(0, 0.02)  # Adjust the range for the x-axis
plt.ylim(0, 0.02)  # Adjust the range for the y-axis

# Optionally, add grid lines
# plt.grid(True)

# Optionally, save the plot
# plt.savefig("fitness_of_TN_abundances_03_01_2024_37oC_1a.png", dpi=600, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
x_column = (df['normalized_50_A1'] + df['normalized_50_A2']) / 2
y_column = (df['normalized_50_B1'] + df['normalized_50_B2']) / 2

# Create a scatter plot using the calculated means
plt.scatter(x_column, y_column, color='black')
plt.xlabel('50A Abundance', fontsize=14)
plt.ylabel('50B Abundance', fontsize=14)
plt.title('Plot of TN insertion abundances at 50°C (Bioreps)', fontsize=16, color='purple')

# Adjust the x and y-axis scale ranges
plt.xlim(0, 0.02)  # Adjust the range for the x-axis
plt.ylim(0, 0.02)  # Adjust the range for the y-axis

# Optionally, add grid lines
# plt.grid(True)

# Optionally, save the plot
# plt.savefig("fitness_of_TN_abundances_03_01_2024_37oC_1a.png", dpi=600, bbox_inches='tight')

# Show the plot
#plt.show()
# Out:
# (0.0, 0.02)

# %% [markdown]
# ### Plots of 37 oC against 50 oC

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
x_column = (df['normalized_37_A1'] + df['normalized_37_A2'] + df['normalized_37_B1'] + df['normalized_37_B2']) / 4
y_column = (df['normalized_50_A1'] + df['normalized_50_A2'] + df['normalized_50_B1'] + df['normalized_50_B2']) / 4

# Create a scatter plot using the calculated means
plt.scatter(x_column, y_column, color='black')
plt.xlabel('37 oC Abundance', fontsize=14)
plt.ylabel('50 oC Abundance', fontsize=14)
plt.title('Plot of TN insertion abundances (37 oC vs 50 oC)', fontsize=16, color='purple')

# Adjust the x and y-axis scale ranges
plt.xlim(0, 0.02)  # Adjust the range for the x-axis
plt.ylim(0, 0.015)  # Adjust the range for the y-axis

# Optionally, add grid lines
# plt.grid(True)

# Optionally, save the plot
# plt.savefig("fitness_of_TN_abundances_03_01_2024_37oC_1a.png", dpi=600, bbox_inches='tight')

# Show the plot

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
x_column = (df['normalized_37_A1'] + df['normalized_37_A2'] + df['normalized_37_B1'] + df['normalized_37_B2']) / 4
y_column = (df['normalized_50_A1'] + df['normalized_50_A2'] + df['normalized_50_B1'] + df['normalized_50_B2']) / 4

# Create a scatter plot using the calculated means
plt.figure(figsize=(8, 6))
plt.scatter(x_column, y_column, color='black')
plt.xlabel('37 oC Abundance', fontsize=14)
plt.ylabel('50 oC Abundance', fontsize=14)
plt.title('Plot of TN insertion abundances (37 oC vs 50 oC)', fontsize=16, color='purple')

# Adjust the x and y-axis scale ranges
plt.xlim(0, 0.02)
plt.ylim(0, 0.015)

# Annotating the points with gene names based on a threshold
threshold_x = 0.005  # Set threshold for x-axis abundance
threshold_y = 0.006 # Set threshold for y-axis abundance

for i, (xi, yi, gene) in enumerate(zip(x_column, y_column, df['gene'])):
    if xi > threshold_x or yi > threshold_y:  # Adjust condition as needed
        plt.annotate(gene, 
                     (xi, yi), 
                     textcoords="offset points", 
                     xytext=(0, 10), 
                     ha='center', 
                     fontsize=9, 
                     color='red')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
x_column = (df['normalized_37_A1'] + df['normalized_37_A2'] + df['normalized_37_B1'] + df['normalized_37_B2']) / 4
y_column = (df['normalized_50_A1'] + df['normalized_50_A2'] + df['normalized_50_B1'] + df['normalized_50_B2']) / 4

# Create a scatter plot using the calculated means
plt.figure(figsize=(12, 10))  # Increased figure size
plt.scatter(x_column, y_column, color='black')
plt.xlabel('37 oC Abundance', fontsize=14)
plt.ylabel('50 oC Abundance', fontsize=14)
plt.title('Plot of TN insertion abundances (37 oC vs 50 oC)', fontsize=16, color='purple')

# Adjust the x and y-axis scale ranges
plt.xlim(0, 0.015)
plt.ylim(0, 0.015)

# Annotating a limited number of the most abundant points
num_annotations = 50  # Number of points to annotate
df['x_mean'] = x_column
df['y_mean'] = y_column

# Sort by abundance (sum of x and y) to find the top N points to annotate
top_df = df.sort_values(by=['x_mean', 'y_mean'], ascending=False).head(num_annotations)

for i, row in top_df.iterrows():
    gene, xi, yi = row['gene'], row['x_mean'], row['y_mean']
    if pd.notna(gene):  # Check if the gene name is not NaN
        plt.annotate(gene, 
                     (xi, yi), 
                     textcoords="offset points", 
                     xytext=(5, 5),  # Offset for better visibility
                     arrowprops=dict(arrowstyle='->', color='red'),  # Arrow to the point
                     fontsize=9, 
                     color='red')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
x_column = (df['normalized_37_A1'] + df['normalized_37_A2'] + df['normalized_37_B1'] + df['normalized_37_B2']) / 4
y_column = (df['normalized_50_A1'] + df['normalized_50_A2'] + df['normalized_50_B1'] + df['normalized_50_B2']) / 4

# Create a scatter plot using the calculated means
plt.figure(figsize=(12, 10))  # Increased figure size
plt.scatter(x_column, y_column, color='black')
plt.xlabel('37 oC Abundance', fontsize=14)
plt.ylabel('50 oC Abundance', fontsize=14)
plt.title('Plot of TN insertion abundances (37 oC vs 50 oC)', fontsize=16, color='purple')

# Adjust the x and y-axis scale ranges
plt.xlim(0, 0.004)
plt.ylim(0, 0.004)

# Annotating a limited number of the most abundant points
num_annotations = 50  # Number of points to annotate
df['x_mean'] = x_column
df['y_mean'] = y_column

# Sort by abundance (sum of x and y) to find the top N points to annotate
top_df = df.sort_values(by=['x_mean', 'y_mean'], ascending=False).head(num_annotations)

for i, row in top_df.iterrows():
    gene, xi, yi = row['gene'], row['x_mean'], row['y_mean']
    if pd.notna(gene):  # Check if the gene name is not NaN
        plt.annotate(gene, 
                     (xi, yi), 
                     textcoords="offset points", 
                     xytext=(5, 5),  # Offset for better visibility
                     arrowprops=dict(arrowstyle='->', color='red'),  # Arrow to the point
                     fontsize=9, 
                     color='red')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Load the data from the CSV file into a DataFrame
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/all_fastqs_available/TNSeq_barseq_outputs_using_all_fastqs_combined_13k_mutants_37•C_vs_50•C_10_28_2024/poolCount_37•C_vs_50•C.txt', sep='\t')

# Calculate the mean of the specified columns for x and y axes
df['x_mean'] = (df['normalized_37_A1'] + df['normalized_37_A2'] + df['normalized_37_B1'] + df['normalized_37_B2']) / 4
df['y_mean'] = (df['normalized_50_A1'] + df['normalized_50_A2'] + df['normalized_50_B1'] + df['normalized_50_B2']) / 4

# Create an interactive scatter plot using plotly
fig = px.scatter(
    df,
    x='x_mean',
    y='y_mean',
    hover_name='gene',  # Display gene name on hover
    labels={
        'x_mean': '37 oC Abundance',
        'y_mean': '50 oC Abundance'
    },
    title='Interactive Plot of TN Insertion Abundances (37 oC vs 50 oC)'
)

# Set the axis ranges
fig.update_xaxes(range=[0, 0.02])
fig.update_yaxes(range=[0, 0.015])

# Show the interactive plot
fig.show()

# %% [markdown]
# # To do statistical t-test

# %% [markdown]
# ### To handle rows where some values are zero and convert them to NaN before performing the Mann-Whitney U test

# %%
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu

# Load the dataset
df = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/TNSeq_13k_mutants_mapping_output/TNSeq_barseq_outputs_using_combined_tnseq_poolfile_all_temp_05_23_2024/normalized_barseq_pool_counts_05_28_2024.csv')

# Convert all columns to numeric, coercing errors to NaN
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Replace zeros with NaN
df.replace(0, np.nan, inplace=True)

# Define the data columns for the existing and new conditions
data_37C = df[['KFRB007_1', 'KFRB008_1', 'KFRB019_1', 'KFRB020_1']]
data_45C = df[['KFRB021_1', 'KFRB022_1', 'KFRB023_1', 'KFRB024_1']]
data_50C = df[['KFRB025_1', 'KFRB026_1', 'KFRB027_1', 'KFRB028_1']]



# List to store p-values for existing conditions
p_values_37_vs_45 = []
p_values_37_vs_50 = []

# Iterate over rows and perform Mann-Whitney U test for each
for index, row in df.iterrows():
    # Drop NaN values from the datasets
    data_37C_values = row[data_37C.columns].dropna()
    data_45C_values = row[data_45C.columns].dropna()
    
    # Perform the Mann-Whitney U test for 37C vs. 45C
    if len(data_37C_values) > 0 and len(data_45C_values) > 0:
        statistic, p_value = mannwhitneyu(data_37C_values, data_45C_values, alternative='two-sided')
        p_values_37_vs_45.append(p_value)
    else:
        p_values_37_vs_45.append(np.nan)

    # Perform the Mann-Whitney U test for 37C vs. 50C
    #data_37C_values = row[data_25C.columns].dropna()
    data_50C_values = row[data_50C.columns].dropna()

    if len(data_37C_values) > 0 and len(data_50C_values) > 0:
        statistic, p_value = mannwhitneyu(data_37C_values, data_50C_values, alternative='two-sided')
        p_values_37_vs_50.append(p_value)
    else:
        p_values_37_vs_50.append(np.nan)

# Add the p-values to the DataFrame
df['MannWhitneyU_p_value_37_vs_45'] = p_values_37_vs_45
df['MannWhitneyU_p_value_37_vs_50'] = p_values_37_vs_50

# Save the DataFrame with the calculated p-values to a new CSV file
output_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/for_analysis/TNSeq_13k_mutants_mapping_output/TNSeq_barseq_outputs_using_combined_tnseq_poolfile_all_temp_05_23_2024/output_with_mannwhitneyu_p_values_zero_values_removed_combined.csv'
df.to_csv(output_path, index=False)
