# %%
from Bio import SeqIO

def merge_fasta(files, output_file):
    with open(output_file, 'w') as outfile:
        for file in files:
            for record in SeqIO.parse(file, 'fasta'):
                SeqIO.write(record, outfile, 'fasta')

# Example usage
files_to_merge = ['/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_10_mins/TNSeq_merge_FASTQ/OORBO28_S1_L001_merged.fastq', '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_15_mins/TNSeq_merge_FASTQ/OORBO29_S1_L001_merged.fastq', '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_20_mins/TNSeq_merge_FASTQ/OORBO30_S1_L001_merged.fastq']
merge_fasta(files_to_merge, '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/TNSeq_merge_FASTQ/all_digestion_time_merged.fastq')

# %% [markdown]
# ## to count total number of reads

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_10_mins/TNSeq_merge_FASTQ/OORBO28_S1_L001_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 1279040

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_15_mins/TNSeq_merge_FASTQ/OORBO29_S1_L001_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 1254821

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_20_mins/TNSeq_merge_FASTQ/OORBO30_S1_L001_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 1314803

# %%
from Bio import SeqIO

def merge_fastq(files, output_file):
    with open(output_file, 'w') as outfile:
        for file in files:
            for record in SeqIO.parse(file, 'fastq'):
                SeqIO.write(record, outfile, 'fastq')

# Example usage
files_to_merge = ['/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_10_mins/TNSeq_merge_FASTQ/OORBO28_S1_L001_merged.fastq', '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_15_mins/TNSeq_merge_FASTQ/OORBO29_S1_L001_merged.fastq', '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/digestion_time_20_mins/TNSeq_merge_FASTQ/OORBO30_S1_L001_merged.fastq']
merge_fastq(files_to_merge, '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/TNSeq_merge_FASTQ/all_digestion_time_merged.fastq')

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/TNSeq_merge_FASTQ/all_digestion_time_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 3848664
