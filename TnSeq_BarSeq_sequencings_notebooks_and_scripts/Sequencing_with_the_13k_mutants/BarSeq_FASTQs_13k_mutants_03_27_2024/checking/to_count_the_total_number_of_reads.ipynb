# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/KFRB019_S1_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 556852

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/Tnseq_fastq_files_jumpstart_polymerase/TNSeq_merge_FASTQ/fastq_file_for_two_sequencing_batches_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 1331161

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/TnSeq_11k_diff_digestion_time/TNSeq_merge_FASTQ/all_digestion_time_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 3848664

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/Tnseq_fastq_files/all_available_fastq_merged/all_batches_together_06_12_2024_merged.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 5179825

# %%
BARSEQ FILES WITH 500 MILLION reads generated

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/37A1_S1_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 40263692

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/37A2_S2_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
# Out:
# Total number of reads: 39219999

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/37B1_S3_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/37B2_S4_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/50A1_S5_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/50A2_S6_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/50B1_S7_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')

# %%
def count_reads_in_fastq(file_path):
    with open(file_path, 'r') as file:
        count = 0
        for line in file:
            if line.startswith('@'):
                count += 1
    return count

# Example usage:
file_path = '/usr2/people/shollyt22/shollyt22/TnSeq_BarSeq_sequencings/Sequencing_with_the_13k_mutants/BarSeq_FASTQs_13k_mutants_03_27_2024/Barseq_37•C_vs_50•C_500_million_reads/50B2_S8_L001_R1_001.fastq'
total_reads = count_reads_in_fastq(file_path)
print(f'Total number of reads: {total_reads}')
