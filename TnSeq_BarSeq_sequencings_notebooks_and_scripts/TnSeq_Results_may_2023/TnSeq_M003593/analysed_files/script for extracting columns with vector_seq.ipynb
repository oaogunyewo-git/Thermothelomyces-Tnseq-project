# %%
import pandas as pd

# %%
data_frame = pd.read_csv('/usr2/people/shollyt22/shollyt22/TnSeq_Results_may_2023/TnSeq_M003593/analysed_files/output_with_vector_seq_06_28_2023OORB001_S1_L001_R1_001.fastq_mapped_reads', sep='\t', header=None)

# %%
condition = data_frame[1].str.contains('vector_seq', case=False)
filtered_data = data_frame.loc[condition, [0, 8, 9]]
sorted_data = filtered_data.sort_values(by=8)
print(sorted_data)
# Out:
#                                                      0     8     9
# 133328  @M02248:440:000000000-DKT2B:1:1102:13008:10297    40    88
# 69164   @M02248:440:000000000-DKT2B:1:1101:28464:18633    79   129
# 8509     @M02248:440:000000000-DKT2B:1:1101:18393:5270    79   116
# 9155      @M02248:440:000000000-DKT2B:1:1101:8483:5473    79   126
# 97487   @M02248:440:000000000-DKT2B:1:1101:20805:25691    79   129
# ...                                                ...   ...   ...
# 68466    @M02248:440:000000000-DKT2B:1:1101:9810:18477  7612  7570
# 144703  @M02248:440:000000000-DKT2B:1:1102:20793:12738  7612  7583
# 165463  @M02248:440:000000000-DKT2B:1:1102:25734:17055  7612  7582
# 70394   @M02248:440:000000000-DKT2B:1:1101:12044:18936  7612  7582
# 37642   @M02248:440:000000000-DKT2B:1:1101:21290:12068  7612  7582
#
# [75107 rows x 3 columns]
