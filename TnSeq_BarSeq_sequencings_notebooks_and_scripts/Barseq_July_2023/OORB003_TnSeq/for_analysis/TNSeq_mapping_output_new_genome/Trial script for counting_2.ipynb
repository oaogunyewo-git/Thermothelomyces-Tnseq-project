# %%
# Step 1: Read and Parse the Text File
data_file = '/usr2/people/shollyt22/shollyt22/Barseq_July_2023/OORB003_TnSeq/for_analysis/TNSeq_mapping_output_new_genome/Tnseq_07312023_poolfile'  # Replace with the path to your text file
insertion_counts = {}

with open(data_file, 'r') as file:
    header = file.readline()  # Read and skip the header row
    for line in file:
        fields = line.strip().split('\t')
        insertion_site = (fields[4], int(fields[6]))
        read_count = int(fields[2])  # Assuming "nTot" field contains the read count
        # You may need to adjust the indices based on the columns' positions in your text file

        # Step 2: Count Reads per Insertion
        insertion_counts[insertion_site] = insertion_counts.get(insertion_site, 0) + read_count

# Step 3: Write Output
output_file = '/usr2/people/shollyt22/shollyt22/Barseq_July_2023/OORB003_TnSeq/for_analysis/TNSeq_mapping_output_new_genome/For_counting/unique_insertions_5reads.txt'  # Replace with your desired output file path

with open(output_file, 'w') as out_file:
    for insertion_site, count in insertion_counts.items():
        scaffold, position = insertion_site
        out_file.write(f'{scaffold}\t{position}\t{count}\n')
